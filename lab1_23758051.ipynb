# %%
from google.colab import auth
auth.authenticate_user()

# Konfigurasi identitas GitHub
# !git config --global user.email "rsafei731@gmail.com"
# !git config --global user.name "RahmatHadinata23758051"

# Gunakan akses token yang disimpan sebagai secret (lebih aman daripada hardcoding)
access_token = "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"
repo_owner = "IET-Polinela"
repo_name = "intro-to-colab-RahmatHadinata23758051"

# Cloning repository
# !git clone https://{access_token}@github.com/{repo_owner}/{repo_name}.git

# Masuk ke direktori repository
# %cd {repo_name}
# Out:
# Cloning into 'intro-to-colab-RahmatHadinata23758051'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15 (delta 2), reused 12 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 74.16 KiB | 5.70 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/intro-to-colab-RahmatHadinata23758051

# %%
# !python iris_knn.py
# Out:
# 2025-03-03 04:00:03.999971: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740974404.027777     522 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740974404.035580     522 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:00:04.062038: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %%writefile iris_knn.py
# Out:
# Overwriting iris_knn.py

# %%
# %%writefile iris_knn.py
# Out:
# Overwriting knn_confusion_matrix.png

# %%
# !python iris_knn.py
# Out:
# Accuracy: 1.00
# Figure(600x400)

# %%
# !git add .
# !git commit -m “training_performance.png”
# !git push origin main
# Out:
# [main 6c0d2c0] “training_performance.png”
#  2 files changed, 2 insertions(+)
#  create mode 100644 evaluation.txt
#  create mode 100644 training_performance.png
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 52.69 KiB | 17.56 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/IET-Polinela/intro-to-colab-RahmatHadinata23758051.git
#    aa5fcc3..6c0d2c0  main -> main

# %%
# !git add .
# !git commit -m “lab1_23758051.ipynb”
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
from google.colab import auth
auth.authenticate_user()

# Konfigurasi identitas GitHub
# !git config --global user.email "rsafei731@gmail.com"
# !git config --global user.name "RahmatHadinata23758051"

# Gunakan akses token yang disimpan sebagai secret (lebih aman daripada hardcoding)
access_token = "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"
repo_owner = "IET-Polinela"
repo_name = "intro-to-colab-RahmatHadinata23758051"

# Cloning repository
# !git clone https://{access_token}@github.com/{repo_owner}/{repo_name}.git

# Masuk ke direktori repository
# %cd {repo_name}
# Out:
# Cloning into 'intro-to-colab-RahmatHadinata23758051'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15 (delta 2), reused 12 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 74.16 KiB | 2.97 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/intro-to-colab-RahmatHadinata23758051

# %%
# !python mnist_cnn.py
# Out:
# 2025-03-03 04:09:30.847763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740974970.871389    1409 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740974970.880020    1409 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:09:30.911695: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python mnist_cnn.py
# Out:
# 2025-03-03 04:14:31.088868: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740975271.107778    2842 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740975271.113394    2842 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:14:31.132463: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python mnist_cnn.py
# Out:
# 2025-03-03 04:17:07.458166: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740975427.472927    1871 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740975427.477234    1871 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-03 04:17:07.491706: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/My Drive/lab1_23758051.ipynb" "/content/intro-to-colab-RahmatHadinata23758051]/"
# Out:
# cp: cannot create regular file '/content/[intro-to-colab-RahmatHadinata23758051]/': Not a directory
